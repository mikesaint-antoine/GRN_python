# %% [markdown]
# # Testing Simulation Functions
#
# The goal of this notebook is to test out functions in the simulation.py file. These functions are all related to simulating different gene regulatory interactions and network motifs, including both deterministic and stochastic simulations.
#
# The following **stochastic simulations** are currently available:
# - 2-Gene Toggle Switch
# - 2-Gene Hill Activation
# - 2-Gene Hill Repression
#
# The following **deterministic simulations** are currently available:

# %%
import numpy as np
import simulation
import matplotlib.pyplot as plt

# %%
## TOGGLE SWITCH SSA
# simulation.toggle_switch_ssa(get_info=1)
[G1,G2,t] = simulation.toggle_switch_ssa(plot_fig=1)

# %%
## HILL ACTIVATION SSA
[G1,G2,t] = simulation.hill_activation_ssa(tend=50,plot_fig=1)

# %%
## HILL REPRESSION SSA
[G1,G2,t] = simulation.hill_activation_ssa(tend=100,plot_fig=1,init=[0,20])

# %%
## NO INTERACTION SSA
[G1,G2,t] = simulation.no_interaction_ssa(tend=100,plot_fig=1)
